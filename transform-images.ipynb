# %%
pip install pandas==1.2.1
# Out:
# ...
# WARNING: You are using pip version 21.0; however, version 21.0.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install import_ipynb==0.1.3
# Out:
# ...
# WARNING: You are using pip version 21.0; however, version 21.0.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.

# %%
import import_ipynb
from codait_utils import *
# Out:
# importing Jupyter notebook from codait_utils.ipynb

# %%
unzip('.','images.zip')
# Out:
# /bin/bash: unzip: command not found

# %%
import os
source_folder = os.environ.get('source_folder','images')
target_column = os.environ.get('target_column','finding')
image_column = os.environ.get('image_column','filename')
output_folder = os.environ.get('output_folder','data')

# %%
import pandas as pd

# %%
metadata = pd.read_csv('metadata.csv')

# %%
import os
os.mkdir(output_folder)

# %%
folders = metadata[target_column].unique()

# %%
for folder in folders:
    os.mkdir(output_folder+'/'+folder)

# %%
#hack
metadata = metadata[~metadata.filename.str.contains(".gz")]

# %%
from shutil import copyfile

for index, row in metadata.iterrows():
    file_name = row[image_column]
    class_name = row[target_column]
    #print(source_folder+'/'+file_name +':'+ output_folder+'/'+file_name)
    copyfile(source_folder+'/'+file_name, output_folder+'/'+class_name+'/'+file_name)

# %%
# !tree data
# Out:
# data
# ├── No Finding
# │   ├── 000001-3.jpg
# │   ├── 000001-6.jpg
# │   ├── 02b973e10caa192fd4e6825ad4aeaf_jumbo-10.jpeg
# │   ├── 10.1016-slash-j.hrcr.2020.04.015-fig3-a.png
# │   ├── 16630_1_1.jpg
# │   ├── 16631_1_1.jpg
# │   ├── 16631_1_2.jpg
# │   ├── 16745_2_1.PNG
# │   ├── 16745_3_1.png
# │   ├── 16745_6_1.png
# │   ├── 16755_1_1.jpg
# │   ├── 1-s2.0-S1059131120301151-gr2-e.png
# │   ├── 1-s2.0-S1341321X20301124-gr3_lrg-a.png
# │   ├── 1-s2.0-S1341321X20301124-gr3_lrg-b.png
# │   ├── 1-s2.0-S2213716520301168-gr1_lrg-c.png
# │   ├── 1-s2.0-S2214250920300834-gr1_lrg-d.png
# │   ├── 2c35005f.jpg
# │   ├── 5083A6B7-8983-472E-A427-570A3E03DDEE.jpeg
# │   ├── 665f7ed5dcf52f235d8abed8cc200c_jumbo.jpeg
# │   ├── ada8c494.jpg
# │   ├── covid-19-pneumonia-58-prior.jpg
# │   └── F051E018-DAD1-4506-AD43-BE4CA29E960B.jpeg
# ├── Pneumonia
# │   ├── 000001-11.jpg
# │   ├── 000001-12.jpg
# │   ├── 000001-13.jpg
# │   ├── 000001-14.jpg
# │   ├── 000001-15.jpg
# │   ├── 000001-24.jpg
# ...

# %%
zipdir('data.zip', 'data')
# Out:
# /bin/bash: zip: command not found
